# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snsi

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
# !unzip archive.zip
# Out:
# unzip:  cannot find or open archive.zip, archive.zip.zip or archive.zip.ZIP.

# %%
# !unzip /content/archive.zip
# Out:
# unzip:  cannot find or open /content/archive.zip, /content/archive.zip.zip or /content/archive.zip.ZIP.

# %% [markdown]
# #  exploring Data Analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 619          620         0       2  Gavey, Mr. Lawrence  male  26.0      0
#
#      Parch Ticket  Fare Cabin Embarked
# 619      0  31028  10.5   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()

# %%
df.columns.to_list()

# %%
for col in df.columns:
    print(col)
    print(df[col].unique())
    print('=' * 50)

# %%
df['Date'].sort_values(ascending=True)

# %%
df.info()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Survived', data=df)
plt.title("Passenger Survival Distribution")
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Count by Gender")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20)
plt.title("Age Distribution of Passengers")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Insights:
#
# 1. Female passengers had a higher survival rate compared to males.
# 2. Most passengers were between 20–40 years old.
# 3. Survival is slightly correlated with passenger class and age.
# 4. The dataset shows patterns that can help understand passenger survival behavior.

# %%
df.head()

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.corr(numeric_only=True)

# %% [markdown]
# # Date

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()

# %%
df.head()

# %%
df['Date'].head()

# %%
df

# %%
df = df.reset_index()

# %%
df['month'] = df['Date'].dt.month

# %%
df

# %%
df_cust = df.groupby(['month'],as_index=False)['Customer ID'].count().sort_values(by='Customer ID',ascending=False)
df_cust

# %%
ax = sns.barplot(x='month',y='Customer ID',data=df_cust,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_Gender = df.groupby(['month'],as_index=False)['Gender'].value_counts()
df_Gender

# %%
ax = sns.barplot(x='month', y='count', hue='Gender', data=df_Gender, palette=sns.color_palette("tab10"))

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df

# %%
df_Quantity = df.groupby(['month'],as_index=False)['Quantity'].sum()
df_Quantity

# %%
ax = sns.barplot(x='month',y='Quantity',data=df_Quantity,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df

# %%
df_Total= df.groupby(['month'],as_index=False)['Total Amount'].sum()
df_Total

# %%
ax = sns.barplot(x='month',y='Total Amount',data=df_Total,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df

# %% [markdown]
# # Customer ID

# %%
df['Customer ID'].value_counts().count()

# %%
df['Customer ID'].describe()

# %% [markdown]
# # Gender

# %%
df_Gend = df['Gender'].value_counts(normalize=True) * 100
df_Gend

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x=df['Gender'],data=df,palette=sns.color_palette("tab10"),width=.5)
plt.legend(['Male','Female'])
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df.groupby(['Gender'])['Age'].mean()

# %%
df_q = df.groupby(['Gender'],as_index=False)['Quantity'].sum()
df_q

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x='Gender',y='Quantity',data=df_q ,palette=sns.color_palette("tab10"),width=.5)
plt.legend(['Male','Female'])
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_totla = df.groupby(['Gender'],as_index=False)['Total Amount'].sum()
df_totla

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x='Gender',y='Total Amount',data=df_totla,palette=sns.color_palette("tab10"),width=.5)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_male_female =  df.groupby(['Gender','month'],as_index=False).size().sort_values(by='month',ascending=False)
df_male_female

# %%
ax = sns.barplot(x='month',y='size',hue='Gender',data=df_male_female,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df

# %% [markdown]
# # 	Age

# %%
df_age = df['Age'].value_counts().sort_values(ascending=False).head()
df_age

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(x='Age',data=df,palette=sns.color_palette())
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_filtered = df[df['Age'] == 43]
df_filtered.groupby(['Gender'],as_index=False).size()

# %%
df_filtered = df[df['Age'] == 64]
df_filtered.groupby(['Gender'],as_index=False).size()

# %%
df_filtered = df[df['Age'] == 37]
df_filtered.groupby(['Gender'],as_index=False).size()

# %%
df_age_to = df.groupby(['Age', 'Gender'])['Total Amount'].mean().reset_index()
df_age_to

# %%
sns.scatterplot(x='Age', y='Total Amount', hue='Gender', data=df_age_to, palette='tab10')
plt.xlabel('Age')
plt.ylabel('Total Amount')
plt.title('Relationship between Age and Total Amount by Gender')

# %%
df_sorted = df.sort_values(by=['Age', 'Gender'])
plt.figure(figsize=(12,6))
sns.lineplot(x='Age', y='Total Amount', hue='Product Category', data=df_sorted, palette='tab10', marker='o')
plt.xlabel('Age')
plt.ylabel('Total Amount')
plt.title('Relationship between Age and Total Amount by Gender')
plt.show()

# %%
df_age_Product = df.groupby(['Product Category'],as_index=False)['Age'].mean()
df_age_Product

# %%
sns.boxplot(data=df,x='Age')
plt.show()

# %%
Q1 = df['Age'].quantile(.25)
Q3 = df['Age'].quantile(.75)
IQR = Q3 - Q1
up = Q3 + 1.5 * (IQR)
lw = Q1 - 1.5 * (IQR)

# %%
print(IQR)
print(f'the Upper Bound is {up} ')
print(f'the lower Bound is {lw} ')

# %%
df

# %% [markdown]
# # Product Category

# %%
Category =  df['Product Category'].value_counts()
Category

# %%
ax  = sns.barplot(x=Category.index,y=Category.values,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_top_Cat = df.groupby(['Product Category','Gender'],as_index=False)['Quantity'].count().sort_values(by='Quantity',ascending=False)
df_top_Cat

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x='Product Category',y='Quantity',hue='Gender',data=df_top_Cat,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_pri = df.groupby(['Product Category'],as_index=False)['Price per Unit'].sum()
df_pri

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x='Product Category',y='Price per Unit',data=df_pri,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_tot = df.groupby(['Product Category'],as_index=False)['Total Amount'].sum()
df_tot

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x='Product Category',y='Total Amount',data=df_tot,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df

# %% [markdown]
# # Quantity

# %%
df['Quantity'].value_counts()

# %%
filter_qun = df[df['Quantity']==4]
filter_qun.groupby(['Product Category'],as_index=False).size()

# %%
df_q_p = df.groupby(['Quantity'],as_index=False)['Price per Unit'].sum()
df_q_p

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x='Quantity',y='Price per Unit',data=df_q_p,palette=sns.color_palette("tab10"))
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
df_q_p = df.groupby(['Quantity'],as_index=False)['month'].size()
df_q_p

# %% [markdown]
# # How do customers adapt their shopping habits during seasonal trends?

# %%
df['season'] = df['month'].apply(lambda x:'Winter' if x in [12,1,2] else ('Spring' if x in [3,4,5] else ('summer' if x in [6,7,8]else'Fall')))

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='season', y='Total Amount', data=df,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='season', y='Total Amount', hue='Gender',ci=None, data=df, palette='tab10')
plt.title('Sales by Season and Gender')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='month', y='Total Amount',hue='Gender', data=df,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
df['Holiday'] = df['Date'].apply(lambda x : 1 if x in pd.to_datetime(['2023-04-21', '2023-07-01']) else 0)

# %%
df['Holiday'].sum()

# %%
Holiday_Sales = df.groupby(['Holiday'],as_index=False)['Total Amount'].sum()
Holiday_Sales

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Holiday', y='Total Amount', data=Holiday_Sales,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
df

# %%
df['Price per Unit'].value_counts()

# %%
df.groupby(['Price per Unit'],as_index=False)['Quantity'].sum()

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Quantity', y='Price per Unit', data=df,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Quantity', y='Price per Unit',hue='Product Category' , data=df,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
df.groupby(['month','Price per Unit'],as_index=False)['Quantity'].count()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='month', y='Price per Unit',hue='Quantity' , data=df,ci=None, palette='tab10')
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
df

# %%
df.groupby(['Product Category','Price per Unit','season'],as_index=False).size()

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(x='Product Category', y='Price per Unit',hue='season' , data=df,ci=None, palette='tab10')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Amount')
plt.show()

# %%
df

# %%
sns.scatterplot(x='Quantity',y='Total Amount',hue='Price per Unit',data=df)
plt.show()

# %% [markdown]
# <h2 style="background: linear-gradient(135deg, #ff7e5f, #feb47b); color:white; padding:15px; text-align:center; border-radius:15px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.4);">
#     Results
# </h2>
# >
# >

# %% [markdown]
# Market Data Analysis Report
# Introduction
# Market data was analyzed to identify patterns and trends in buying and selling throughout the year. This study focuses on monthly purchase patterns by gender, product distribution, and preferred seasons.
#
# ## Monthly Purchase Analysis
# May:
# Highest Visitor Count: May recorded the highest number of visitors with 250 visitors.
# Highest Sales: 250 units of products were sold, compared to 53150 units in October.
# October:
# Recorded the highest sales value with 46580 units, making it one of the standout sales months.
# December:
# Highest Female Visitor Count: December is the month with the highest number of female visitors, totaling 55 women.
#
# ## Gender-Based Purchase Analysis
# Men:
#
# Total Sales: 1216 units.
# Total Amount Paid: 223160.
# Top Purchased Product: Clothing with 177 units sold.
# Women:
#
# Total Sales: 1298 units.
# Total Amount Paid: 232840.
# Top Purchased Product: Clothing with 174 units sold.
#
# ## Most Sold Products
# Clothing: Clothing is the most sold product, with men purchasing 177 units compared to 174 units by women.
# Electronics: Ranked second in sales, with men purchasing 170 units.
# Beauty Products: Women purchased 166 units compared to 141 units by men.
#
# ## Age Analysis
# Most Common Ages: People aged 43, 51, 64, and 75 are the most frequent visitors.
# Women: 19 women aged 43.
# Men: 12 men aged 43.
#
# ## Seasonal and Holiday Impact
# Winter Season: Winter is the most profitable season, with clothing and electronics being the top-selling products during this season.
#
# ## Peak Times:
#
# For Women: January, May, and October.
# For Men: December, July, and June.
# Holidays: Holidays significantly impact sales, with holiday periods recording 1920 in sales compared to 454080 on regular days.
#
# ## Conclusions
# Clothing: The most demanded product, especially among women.
# Winter: The best shopping period with noticeable increases in sales.
# Gender Preferences: Men and women have different preferences for shopping times and seasons.

# %% [markdown]
# <h2 style="background: linear-gradient(135deg, #ff7e5f, #feb47b); color:white; padding:15px; text-align:center; border-radius:15px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.4);">
#     Recommendations for the Upcoming Year
#
# </h2>
# >
# >

# %% [markdown]
# ## Increase Promotion During Profitable Months:
#
# May: Since May recorded the highest number of visitors, consider offering special deals and discounts to attract more customers.
# October: Use October as an opportunity to boost sales through intensive advertising and promotional campaigns.
#
# ## Tailor Offers Based on Gender:
# For Women: Target promotions and products that are in high demand, such as clothing and beauty products. Consider organizing special marketing events for women.
# For Men: Focus on clothing and electronics, which have proven successful, and offer special promotions to attract them during peak periods like December and June.
#
# ## Seasonal Strategy:
# Winter: Enhance promotional campaigns for clothing and electronics during the winter season, focusing on cold months like January and October.
# Seasonal Analysis: Offer discounts on season-specific products to encourage purchases in different seasons.
#
# ## Target Age Groups:
# Age 43: Provide special offers for this age group to attract them with products that meet their needs.
# Design Marketing Strategies: Tailor marketing strategies to the most frequent age groups based on their shopping preferences.
#
# ## Improve Holiday Strategies:
# Advance Planning: Enhance sales and promotional strategies for holidays to avoid disruptions and increase sales during these periods.
# Organize Events: Host special events during holidays to attract more visitors and customers.
#
# ## Regular Data Analysis:
# Performance Review: Conduct periodic analyses to monitor performance and adjust strategies based on the results.
# Collect New Data: Use advanced data analysis techniques to gain new insights and improve sales strategies.
#
# ## Enhance Shopping Experience:
# Website Updates: Improve the user interface and shopping experience online to facilitate easier purchases.
# Customer Service: Enhance customer service and provide effective support to meet customer needs.
#
# ## Innovation in Products and Offers:
# New Products: Introduce new and innovative products that align with current market trends.
# Customized Offers: Create tailored offers based on customer preferences and data analysis

# %% [markdown]
# <h2 style="background: linear-gradient(135deg, #ff7e5f, #feb47b); color:black; padding:15px; text-align:center; border-radius:15px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.4);">
#     Thank you
#
# </h2>
# >
# >

# %% [markdown]
# <h2 style="background: linear-gradient(135deg, #ff7e5f, #feb47b); color:black; padding:15px; text-align:center; border-radius:15px; box-shadow: 0px 4px 12px rgba(0, 0, 0, 0.4);">
#     Eng / Ahmed Ayman
#
# </h2>
# >
# >
